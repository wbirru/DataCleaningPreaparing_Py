# %% [markdown]
# # Task 1: Data Preparation
#
# You will start by loading the CSV data from the file (using appropriate pandas functions) and checking whether the loaded data is equivalent to the data in the source CSV file.
#
# Then, you need to clean the data by using the knowledge we taught in the lectures. You need to deal with all the potential issues/errors in the data appropriately.
#
# ###### (Please note that this is just a sample template, and please feel free to add more cells to complete of the sub-tasks in the assignment. The following existing cells are for example purposes only.)

# %%
# Import pandas library
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# Load the data from the file NBA_players_stats.csv using pandas library.
NBA_players_P = "/Users/emanuel/Documents/PGinDS-RMIT/Practical_DS_with_Python(2110)_COSC2670/Assignment/assignment1_2021/NBA_players_stats.csv"

# %%
NBA_players = pd.read_csv(NBA_players_P, sep=',', decimal='.')

# %%
# Checking whether the loaded data is equivalent to the data in the source CSV file
NBA_players.shape
# Out:
# (512, 29)

# %%
NBA_players.head(10)
# Out:
#    Rk                    Player  Pos  Age    Tm   G  GS    MP   FG  FGA  ...  \
# 0   1          Precious Achiuwa   PF   21   MIA  35   2   491   84  145  ...
# 1   2              Jaylen Adams   PG   24   MIL   7   0    18    1    8  ...
# 2   3              Steven Adams    C   27   NOP  33  33   918  115  187  ...
# 3   4               Bam Adebayo    C   23   MIA  33  33  1119  236  419  ...
# 4   5         LaMarcus Aldridge    C   35  SAS   21  18   544  115  248  ...
# 5   6         Ty-Shon Alexander   SG   22   PHO   3   0     8    0    3  ...
# 6   7  Nickeil Alexander-Walker  SG    22   NOP  28   3   495   86  211  ...
# 7   8             Grayson Allen   SG   25   MEM  23  12   551   67  164  ...
# 8   9             Jarrett Allen    C   22   TOT  35  17   977  172  257  ...
# 9   9             Jarrett Allen    C   22  BRK   12   5   320   44   65  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF    PTS
# 0  0.543   46   95  141   20   15   19   32  58    212
# 1    NaN    0    3    3    2    0    0    0   1  20000
# 2  0.443  133  161  294   69   29   20   50  63    265
# 3  0.847   72  241  313  179   29   34   98  80    634
# 4  0.838   17   77   94   36    8   18   20  36  28800
# 5    NaN    0    1    1    1    0    0    0   1      0
# 6  0.800    5   61   66   54   28    9   32  44    230
# 7  0.895    8   57   65   50   23    3   21  30    214
# 8  0.741  111  235  346   60   16   59   54  55    471
# 9  0.754   38   87  125   20    7   19   22  21    134
#
# [10 rows x 29 columns]

# %%
#Sanity Check 1
NBA_players.dropna().boxplot(column='PTS', by='Pos')
plt.show()

# %%
#Sanity Check 2
NBA_players.dropna().boxplot(column='Age')
plt.show()

# %%
# Sanity Check 3
NBA_players['PTS'].plot(kind='box')
plt.show()

# %%
# Clean the data
# Removing white spaces
for column in NBA_players.columns: 
    NBA_players['Player'] = NBA_players['Player'].apply(lambda x: str(x).replace(' ', ''))
    NBA_players['Pos'] = NBA_players['Pos'].apply(lambda x: str(x).replace(' ', ''))
    NBA_players['Tm'] = NBA_players['Tm'].apply(lambda x: str(x).replace(' ', ''))

# %%
# Rounding to three decimal places
NBA_players_rounded = NBA_players.round(decimals=3)

# %%
# Displaying information about the NBA players dataframe
NBA_players_rounded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      512 non-null    int64
#  1   Player  512 non-null    object
#  2   Pos     512 non-null    object
#  3   Age     512 non-null    int64
#  4   Tm      512 non-null    object
#  5   G       512 non-null    int64
#  6   GS      512 non-null    int64
#  7   MP      512 non-null    int64
#  8   FG      512 non-null    int64
#  9   FGA     512 non-null    int64
#  10  FG%     509 non-null    float64
#  11  3P      512 non-null    int64
#  12  3PA     512 non-null    int64
#  13  3P%     479 non-null    float64
#  14  2P      512 non-null    int64
#  15  2PA     512 non-null    int64
#  16  2P%     505 non-null    float64
#  17  FT      512 non-null    int64
#  18  FTA     512 non-null    int64
#  19  FT%     480 non-null    float64
#  20  ORB     512 non-null    int64
#  21  DRB     512 non-null    int64
#  22  TRB     512 non-null    int64
#  23  AST     512 non-null    int64
#  24  STL     512 non-null    int64
#  25  BLK     512 non-null    int64
#  26  TOV     512 non-null    int64
#  27  PF      512 non-null    int64
#  28  PTS     512 non-null    int64
# dtypes: float64(4), int64(22), object(3)
# memory usage: 116.1+ KB

# %%
# Cheking how many null values available in the NBA players dataframe
NBA_players_rounded.isnull().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        3
# 3P         0
# 3PA        0
# 3P%       33
# 2P         0
# 2PA        0
# 2P%        7
# FT         0
# FTA        0
# FT%       32
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %%
# Fill all the empty/null values with 0 
NBA_players_Fill = NBA_players_rounded.fillna(0)

# %%
# Cheking whether tha null values are replaced by 0 values
NBA_players_Fill.isnull().sum()
# Out:
# Rk        0
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# dtype: int64

# %%
# Replacing typos with correct column names 
NBA_players_Fill['Pos'] = NBA_players_Fill['Pos'].replace(['SGa', 'SF.', 'PFa', 'sf', 'Sf', 'pg', 'sg', 'Pg'], ['SG', 'SF', 'PF', 'SF', 'SF', 'PG', 'SG', 'PG'])
NBA_players_Fill['Pos'].str.upper()
# Out:
# 0      PF
# 1      PG
# 2       C
# 3       C
# 4       C
#        ..
# 507    SG
# 508    PF
# 509    PG
# 510     C
# 511     C
# Name: Pos, Length: 512, dtype: object

# %%
# Replacing impossible value in Age column
NBA_players_Fill['Age'] = NBA_players_Fill['Age'].replace([-19], 19)

# %%
# Checking whether the error is fixed on not on index number 197
Y = NBA_players_Fill['Age']
Y [197]
# Out:
# 19

# %%
# Replacing impossible values in PTS as they are greater than 2000
NBA_players_Fill['PTS'] = NBA_players_Fill['PTS'].replace([20000, 28800], 0)

# %%
#Checking the dataframe
NBA_players_Fill.head(10)
# Out:
#    Rk                   Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0   1          PreciousAchiuwa  PF   21  MIA  35   2   491   84  145  ...
# 1   2              JaylenAdams  PG   24  MIL   7   0    18    1    8  ...
# 2   3              StevenAdams   C   27  NOP  33  33   918  115  187  ...
# 3   4               BamAdebayo   C   23  MIA  33  33  1119  236  419  ...
# 4   5         LaMarcusAldridge   C   35  SAS  21  18   544  115  248  ...
# 5   6         Ty-ShonAlexander  SG   22  PHO   3   0     8    0    3  ...
# 6   7  NickeilAlexander-Walker  SG   22  NOP  28   3   495   86  211  ...
# 7   8             GraysonAllen  SG   25  MEM  23  12   551   67  164  ...
# 8   9             JarrettAllen   C   22  TOT  35  17   977  172  257  ...
# 9   9             JarrettAllen   C   22  BRK  12   5   320   44   65  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 0  0.543   46   95  141   20   15   19   32  58  212
# 1  0.000    0    3    3    2    0    0    0   1    0
# 2  0.443  133  161  294   69   29   20   50  63  265
# 3  0.847   72  241  313  179   29   34   98  80  634
# 4  0.838   17   77   94   36    8   18   20  36    0
# 5  0.000    0    1    1    1    0    0    0   1    0
# 6  0.800    5   61   66   54   28    9   32  44  230
# 7  0.895    8   57   65   50   23    3   21  30  214
# 8  0.741  111  235  346   60   16   59   54  55  471
# 9  0.754   38   87  125   20    7   19   22  21  134
#
# [10 rows x 29 columns]

# %%
#Saving the cleaned csv file into a new file
NBA_players_Fill.to_csv('cleaned_NBA_players_stats.csv', index=False)

# %%
"""
Make sure that you write the final cleaned dataframe object into a csv file
XXXXX.to_csv('cleaned_NBA_players_stats.csv', index=False)
Please replace XXXXX with your dataframe variable.
"""
# Out:
# "\nMake sure that you write the final cleaned dataframe object into a csv file\nXXXXX.to_csv('cleaned_NBA_players_stats.csv', index=False)\nPlease replace XXXXX with your dataframe variable.\n"

# %% [markdown]
# # Task 2: Data Exploration

# %% [markdown]
# ## Task 2.1
# Explore the players' total points: Please analyze the composition of the total points of the top five players with the most points.

# %%
# Code goes after this line by adding cells

# %%
# Analyzing the total points of the top five players
sorted_NBA_players = NBA_players_Fill.sort_values(by='PTS', ascending = False)

# %%
sorted_NBA_players.head(10)
# Out:
#       Rk                Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 38    37           BradleyBeal  SG   27  WAS  32  32  1143  368  764  ...
# 110  109          StephenCurry  PG   32  GSW  35  35  1194  343  718  ...
# 13    12  GiannisAntetokounmpo  PF   26  MIL  35  35  1189  368  661  ...
# 277  268         DamianLillard  PG   30  POR  34  34  1224  315  708  ...
# 240  237           NikolaJokić   C   25  DEN  36  36  1293  379  668  ...
# 265  258            ZachLaVine  SG   25  CHI  34  34  1209  350  667  ...
# 231  228           LeBronJames  PG   36  LAL  36  36  1245  350  687  ...
# 119  118            LukaDončić  PG   21  DAL  32  32  1125  319  668  ...
# 133  132            JoelEmbiid   C   26  PHI  30  30   990  285  547  ...
# 509  490             TraeYoung  PG   22  ATL  34  34  1182  262  610  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 38   0.903   43  131  174  151   44   14  105   82  1053
# 110  0.934   17  174  191  221   46    2  111   64  1039
# 13   0.661   64  344  408  205   44   49  128  106  1015
# 277  0.933   15  130  145  271   35    9  111   53  1013
# 240  0.881  101  296  397  309   58   23  114  107   977
# 265  0.857   25  152  177  173   37   14  133   90   976
# 231  0.692   21  268  289  280   41   22  135   56   930
# 119  0.757   27  242  269  287   32   22  133   64   916
# 133  0.856   65  283  348   98   37   41   96   75   905
# 509  0.878   25  117  142  321   30    8  149   70   897
#
# [10 rows x 29 columns]

# %%
# Composition of the total points of the top five players with the most points
Top_5_Most_PTS = sorted_NBA_players[0:5][['Player','2P','3P', '2PA', '3PA']]
Top_5_Most_PTS.reset_index(drop=True, inplace=True)

# %%
Top_5_Most_PTS
# Out:
#                  Player   2P   3P  2PA  3PA
# 0           BradleyBeal  294   74  543  221
# 1          StephenCurry  174  169  307  411
# 2  GiannisAntetokounmpo  329   39  524  137
# 3         DamianLillard  169  146  328  380
# 4           NikolaJokić  323   56  534  134

# %%
# Bar plot showing the composition of the total points of the top five players with the most points
Top_5_Most_PTS.plot.bar(stacked = True, title = 'The composition of the total points of the top five players with the most points', 
                    figsize = (8,6))
# Out:
# <AxesSubplot:title={'center':'The composition of the total points of the top five players with the most points'}>

# %% [markdown]
# ## Task 2.2
# Assuming that the data collector makes an entry error when collecting data, it can be ensured that the error occurred in the 3P, 3PA and 3P% columns, but it is not sure which player's information the error lies on. Please try to explore the error by visualization to identify how many errors there are and try to fix it.

# %%
# Code goes after this line by adding cells

# %%
# Ploting box plot for 3P column and checking outliers or impossible values
NBA_players_Fill['3P'].plot(kind='box')
plt.show()

# %%
# Ploting box plot for 3PA column and checking outliers or impossible values
NBA_players_Fill['3PA'].plot(kind='box')
plt.show()

# %%
# Ploting box plot for 3P% column and checking outliers or impossible values
NBA_players_Fill['3P%'].plot(kind='box')
plt.show()

# %%
# Sorting the 3PA values to check the outliers 
sorted_3P_NBA_players = NBA_players.sort_values(by='3PA', ascending = False)

# %%
# Displaying the three columns only to see thier sorted values 
sorted_3P_NBA_players[['3P', '3PA', '3P%']]
# Out:
#       3P  3PA    3P%
# 110  169  411  0.411
# 277  146  380  0.384
# 202  140  370  0.378
# 96   114  308  0.370
# 408  117  299  0.391
# ..   ...  ...    ...
# 195    0    0    NaN
# 196    0    0    NaN
# 243    0    0    NaN
# 304    0    0    NaN
# 0      0    0    NaN
#
# [512 rows x 3 columns]

# %%
# Replacing the 3P outliers with the mean value after calculating the mean
mean3P = sorted_3P_NBA_players['3P'].mean()

# %%
mean3P
# Out:
# 27.21875

# %%
sorted_3P_NBA_players['3P'] = sorted_3P_NBA_players['3P'].replace([169, 146, 140], mean3P)

# %%
# Replacing the 3PA outliers with the mean value after calculating the mean
mean3PA = sorted_3P_NBA_players['3P'].mean()

# %%
mean3PA
# Out:
# 26.48956298828125

# %%
sorted_3P_NBA_players['3PA'] = sorted_3P_NBA_players['3PA'].replace([411, 380, 370], mean3PA)

# %%
# Cheking whether it is replaced by the meann value or not
sorted_3P_NBA_players[['3P', '3PA', '3P%']]
# Out:
#             3P         3PA    3P%
# 110   27.21875   26.489563  0.411
# 277   27.21875   26.489563  0.384
# 202   27.21875   26.489563  0.378
# 96   114.00000  308.000000  0.370
# 408  117.00000  299.000000  0.391
# ..         ...         ...    ...
# 195    0.00000    0.000000    NaN
# 196    0.00000    0.000000    NaN
# 243    0.00000    0.000000    NaN
# 304    0.00000    0.000000    NaN
# 0      0.00000    0.000000    NaN
#
# [512 rows x 3 columns]

# %% [markdown]
# ## Task 2.3
# Please analyze the relationship between the player's total points and the rest features (columns). Please use at least three other columns.

# %%
# Code goes after this line by adding cells

# %%
# Using the scatter matrix code to quickly observe the relationship between the features 
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(NBA_players_Fill,alpha=0.2,figsize=(29,29),diagonal='hist')
plt.show()

# %%
# The relationship between PTS and Field Goals (FT) using scattered plot
NBA_players_Fill.plot(kind='scatter', x='PTS', y="FG")
plt.title ('Players Total Points (PTS) vs Feild Goals (FG)')
plt.xlabel('PTS')
plt.show()

# %%
# The relationship between PTS and Feild Goals Attempts (FTG) using scattered plot
NBA_players_Fill.plot(kind='scatter', x='PTS', y="FGA")
plt.title ('Players Total Points (PTS) vs Feild Goals Attempts (FGA)')
plt.xlabel('PTS')
plt.show()

# %%
# The relationship between PTS and Minutes Played (MP) using scattered plot
NBA_players_Fill.plot(kind='scatter', x='PTS', y="MP")
plt.title ('Players Total Points (PTS) vs Minutes Played (MP)')
plt.xlabel('PTS')
plt.show()
